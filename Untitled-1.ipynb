# %%
 <div id="advanced-filters">
            <a className="btn btn-project-info">Advanced Filters</a>
            {/* <!-- Advanced Search Filters --> */}
            <div className="filters">
              {/* <!-- KYC Dropdown --> */}
              <div className="select"><select id="filter-kyc" aria-label="Default select example" className="select-hidden">
                <option value="">KYC?</option>
                <option value="yes">Yes</option>
                <option value="no">No</option>
              </select><div className="select-styled"><span>KYC?</span></div><ul className="select-options" style="display: none;"><li rel="" className="is-selected">KYC?</li><li rel="yes">Yes</li><li rel="no">No</li></ul></div>

              {/* <!-- KYC Dropdown --> */}
              <div className="select"><select id="filter-status" className="select-hidden">
                <option value="">Status</option>
                <option value="open">Open</option>
                <option value="closed">Closed</option>
              </select><div className="select-styled"><span>Status</span></div><ul className="select-options" style="display: none;"><li rel="" className="is-selected">Status</li><li rel="open">Open</li><li rel="closed">Closed</li></ul></div>

              {/* <!-- Categories Dropdown --> */}

              <div className="select"><select id="filter-category" className="select-hidden">
                <option value="">Categories</option>
                <option value="defi">
                  DeFi                        </option>
                <option value="earn-crypto">
                  Earn Crypto                        </option>
                <option value="featured" selected="">
                  Featured                        </option>
                <option value="new">
                  New                        </option>
                <option value="nft">
                  NFT                        </option>
                <option value="potential-airdrops">
                  Potential                        </option>
                <option value="sponsored">
                  Sponsored                        </option>
              </select><div className="select-styled"><span>
                Featured                        </span></div><ul className="select-options" style="display: none;"><li rel="">Categories</li><li rel="defi">
                  DeFi                        </li><li rel="earn-crypto">
                    Earn Crypto                        </li><li rel="featured" className="is-selected">
                    Featured                        </li><li rel="new">
                    New                        </li><li rel="nft">
                    NFT                        </li><li rel="potential-airdrops">
                    Potential                        </li><li rel="sponsored">
                    Sponsored                        </li></ul></div>


              {/* <!-- Blockchain Dropdown --> */}
              <div className="custom-multiselect-dropdown select-dim">
                <button className="custom-dropbtn">
                  <div className="selected-options-container"></div>
                  <span className="button-text">Blockchain</span>
                  <i className="fa-solid fa-chevron-down custom-arrow"></i>
                </button>
                <div className="custom-dropdown-content">
                  <div className="dropdown-item" data-value="algorand" data-order="0">
                    Algorand                            </div>
                  <div className="dropdown-item" data-value="arbitrum" data-order="1">
                    Arbitrum                            </div>
                  <div className="dropdown-item" data-value="avalanche" data-order="2">
                    Avalanche                            </div>
                  <div className="dropdown-item" data-value="base" data-order="3">
                    Base                            </div>
                  <div className="dropdown-item" data-value="berachain" data-order="4">
                    Berachain                            </div>
                  <div className="dropdown-item" data-value="binance" data-order="5">
                    Binance                            </div>
                  <div className="dropdown-item" data-value="bitcoin" data-order="6">
                    Bitcoin                            </div>
                  <div className="dropdown-item" data-value="blast" data-order="7">
                    Blast                            </div>
                  <div className="dropdown-item" data-value="celestia" data-order="8">
                    Celestia                            </div>
                  <div className="dropdown-item" data-value="cosmos" data-order="9">
                    Cosmos                            </div>
                  <div className="dropdown-item" data-value="dogechain" data-order="10">
                    Dogechain                            </div>
                  <div className="dropdown-item" data-value="ethereum" data-order="11">
                    Ethereum                            </div>
                  <div className="dropdown-item" data-value="fantom" data-order="12">
                    Fantom                            </div>
                  <div className="dropdown-item" data-value="gosh" data-order="13">
                    GOSH                            </div>
                  <div className="dropdown-item" data-value="immutable" data-order="14">
                    Immutable                            </div>
                  <div className="dropdown-item" data-value="injective" data-order="15">
                    Injective                            </div>
                  <div className="dropdown-item" data-value="linea" data-order="16">
                    Linea                            </div>
                  <div className="dropdown-item" data-value="manta-network" data-order="17">
                    Manta Network                            </div>
                  <div className="dropdown-item" data-value="multiversx" data-order="18">
                    MultiversX                            </div>
                  <div className="dropdown-item" data-value="near-protocol" data-order="19">
                    Near Protocol                            </div>
                  <div className="dropdown-item" data-value="optimism" data-order="20">
                    Optimism                            </div>
                  <div className="dropdown-item" data-value="other" data-order="21">
                    Other                            </div>
                  <div className="dropdown-item" data-value="polkadot" data-order="22">
                    Polkadot                            </div>
                  <div className="dropdown-item" data-value="polygon" data-order="23">
                    Polygon                            </div>
                  <div className="dropdown-item" data-value="scroll" data-order="24">
                    Scroll                            </div>
                  <div className="dropdown-item" data-value="solana" data-order="25">
                    Solana                            </div>
                  <div className="dropdown-item" data-value="stellar" data-order="26">
                    Stellar                            </div>
                  <div className="dropdown-item" data-value="testnet" data-order="27">
                    Testnet                            </div>
                  <div className="dropdown-item" data-value="ton" data-order="28">
                    TON                            </div>
                  <div className="dropdown-item" data-value="tron" data-order="29">
                    Tron                            </div>
                  <div className="dropdown-item" data-value="zksync" data-order="30">
                    zkSync                            </div>
                </div>
              </div>

              {/* <!-- Sort By Dropdown --> */}
              <div className="select"><select id="filter-sort" className="select-hidden">
                <option value="">Sort by</option>
                <option value="newest">Newest first</option>
                <option value="ending">Ending soon</option>
              </select><div className="select-styled"><span>Sort by</span></div><ul className="select-options" style="display: none;"><li rel="" className="is-selected">Sort by</li><li rel="newest">Newest first</li><li rel="ending">Ending soon</li></ul></div>

              {/* <!-- Search button --> */}
              <a className="btn btn-project-info" id="airdrop-search-btn">Search</a>
            </div>

          </div>
